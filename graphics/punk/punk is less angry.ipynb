# %%
import requests, zipfile, io
import pandas as pd
from bs4 import BeautifulSoup
import re
import datetime as dt  
import numpy as np
from dotenv import load_dotenv
load_dotenv()
import base64
import os
import requests
import json
pd.set_option('display.max_colwidth', -1)
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
import seaborn as sns

# %matplotlib inline
plt.style.use('fivethirtyeight')

genius_api_key = os.getenv("GENIUS_ACCESS")

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import sys

import altair as alt
import altair_latimes as lat
alt.renderers.enable('notebook')
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')

spotify_client_id = os.getenv("SPOTIFY_CLIENT_ID")
spotify_client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")
token = os.getenv("SPOTIFY_ACCESS_TOKEN")

# %%
filepath = "NRC-Emotion-Lexicon/NRC-Emotion-Lexicon-v0.92/NRC-Emotion-Lexicon-Wordlevel-v0.92.txt"
emolex_df = pd.read_csv(filepath,  names=["word", "emotion", "association"], skiprows=45, sep='\t')
emo_df = emolex_df[((emolex_df.emotion == 'sadness') | (emolex_df.emotion == 'fear')) & (emolex_df.association == 1)]

# %% [markdown]
# # This one uses <code>Spotify's API</code>
# - retains special info
# - refresh my access token every damn hour (https://developer.spotify.com/console/get-track/?id=3n3Ppam7vgaVa1iaRUc9Lp)

# %%
token = f"Bearer {token}"
base_url = "https://api.spotify.com/v1"
headers = {'Authorization': token}
search_url = base_url + "/search"

# searching for artists under the emo genre
params = {'q':'genre:emo', 'type':'artist', 'limit': 10}
response = requests.get(search_url, params=params, headers=headers).json()
# print(response)

songs = []
# looping through the emo artist results
for artist in response['artists']['items']:
    row = {}
    
    row['artist_name'] = artist['name']
    row['artist_popularity'] = artist['popularity']
    row['artist_genres'] = artist['genres']
    row['artist_followers'] = artist['followers']['total']
    
#   pulling the artist from the genre search
    base_url = "https://api.spotify.com/v1"
    headers = {'Authorization': token}
    top_tracks_params = {'country':'from_token', 'id': artist['id']}
    top_tracks_search_url = base_url + "/artists/" + artist['id'] + "/top-tracks"
    response_top_tracks = requests.get(top_tracks_search_url, params=top_tracks_params, headers=headers).json()
    for track in response_top_tracks['tracks'][:3]:
        print(artist['name'], "|", track['name'])
        try:
            row['song_album'] = track['album']['name']
        except:
            row['song_album'] = "nan"
        row['song_title'] = track['name']
        row['song_explicit'] = track['explicit']
        row['song_preview_url'] = track['preview_url']
        row['song_popularity'] = track['popularity']
        row['song_id'] = track['id']
         
        search_url = base_url + "/audio-features/" + track['id']
        response_track_features = requests.get(search_url, headers=headers).json()
        for key in response_track_features.keys():
            row[key] = response_track_features[key]
        
#          scraping the lyrics from Genius        
#         genius_base_url = "http://api.genius.com"
#         genius_headers = {'Authorization': f'Bearer {genius_api_key}'}
#         genius_search_url = genius_base_url + "/search"
#         ## searching using the track name
#         genius_params = {'q': track['name']}
#         response_genius = requests.get(genius_search_url, params=genius_params, headers=genius_headers).json()
#         for hit in response_genius['response']['hits'][:1]:
#             row['lyrics_url'] = base_url + hit['result']['path']
            
#             song_path = hit['result']['api_path']
#             headers = {'Authorization': f'Bearer {genius_api_key}'}
#             song_url = genius_base_url + song_path
#             response = requests.get(song_url, headers=headers)
#             json = response.json()
#             path = json["response"]["song"]["path"]
#             page_url = "http://genius.com" + path
#             page = requests.get(page_url)
#             html = BeautifulSoup(page.text, "html.parser")
#             [h.extract() for h in html('script')]
#             lyrics = html.find("div", class_="lyrics").get_text()
#             lyrics = lyrics.replace('\n', ' ')
#             row['lyrics'] = lyrics.lower()
            
            
            songs.append(row)
        
songs_df = pd.DataFrame(songs)
# Out:
# XXXTENTACION | SAD!
# XXXTENTACION | Moonlight
# XXXTENTACION | Jocelyn Flores
# Panic! At The Disco | High Hopes
# Panic! At The Disco | ME! (feat. Brendon Urie of Panic! At The Disco)
# Panic! At The Disco | Hey Look Ma, I Made It
# 6ix9ine | FEFE
# 6ix9ine | BEBE
# 6ix9ine | KIKA
# Fall Out Boy | Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)
# Fall Out Boy | Centuries
# Fall Out Boy | Sugar, We're Goin Down
# Lil Peep | Falling Down - Bonus Track
# Lil Peep | Save That Shit
# Lil Peep | Star Shopping
# My Chemical Romance | Welcome to the Black Parade
# My Chemical Romance | Teenagers
# My Chemical Romance | I'm Not Okay (I Promise)
# Paramore | Still into You
# Paramore | Ain't It Fun
# Paramore | Hard Times
# iann dior | gone girl
# iann dior | emotions
# iann dior | molly
# Lil Pump | Arms Around You (feat. Maluma & Swae Lee)
# Lil Pump | I Love It (& Lil Pump)
# Lil Pump | Gucci Gang
# Josh A | Suicidal Thoughts
# Josh A | Gucci Coffin
# Josh A | Endless Nightmare

# %%
songs_df.to_csv('spotify_genre_emo.csv', index=False)

# %%
songs_df = pd.read_csv('spotify_genre_emo.csv')
songs_df.sort_values('artist_popularity', ascending=False).artist_name.unique()
# Out:
# array(['XXXTENTACION', 'Panic! At The Disco', 'Fall Out Boy', 'Lil Peep',
#        '6ix9ine', 'Lil Pump', 'Paramore', 'My Chemical Romance',
#        'iann dior', 'Josh A'], dtype=object)

# %%
pop_df = pd.DataFrame(songs_df.groupby('artist_name').song_popularity.mean().sort_values(ascending=False).reset_index())
chart = alt.Chart(pop_df,width=400, height=200).mark_bar().encode(x='song_popularity', y='artist_name')

# %%
# client_credentials_manager = SpotifyClientCredentials(client_id=spotify_client_id, client_secret=spotify_client_secret)
# sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# base_url = "https://api.spotify.com/v1"
# search_url = base_url + "/search"
# # headers = {'Authorization': f"Bearer {spotify_api_key}"}
# # params = {'q': 'genre:emo', 'type': 'artist', 'limit': 1}

# response = sp.search(q='genre:emo', type='artist', limit=1)

# songs = []
# for artist in response['artists']['items']:
#     row = {}
    
#     row['artist_name'] = artist['name']
#     row['artist_popularity'] = artist['popularity']
#     row['artist_genres'] = artist['genres']
    
# #     set up to iterate only through the first track
#     for song in sp.artist_top_tracks(artist['id'], country='US')['tracks'][:2]:
# #         print(song)
#         row['title'] = song['name']
#         row['explicit'] = song['explicit']
#         row['preview'] = song['preview_url']
#         row['popularity'] = song['popularity']
        
#         print(artist['name'], "|", song['name'])
        
#         response_track_features = sp.audio_features(tracks=song['id'])
#         for features in response_track_features:
#             for feature in features.keys():
#                 row[feature] = features[feature]
#             print(sp.track(features['uri']))
            
# #         base_url = "http://api.genius.com"
# #         headers = {'Authorization': f'Bearer {genius_api_key}'}
# #         search_url = base_url + "/search"
# #         artist_name = artist['name']
# #         song_title = song['name']
# #         params = {'q': artist_name + song_title}
# #         response = requests.get(search_url, params=params, headers=headers).json()
# #         for song in response['response']['hits'][:1]:

# #         #     getting some of the meta data
# #             row['lyrics_url'] = base_url + song['result']['path']
            
# #         #  scraping the lyrics from genius
# #             base_url = "http://api.genius.com"
# #             song_path = song['result']['api_path']
# #             headers = {'Authorization': f'Bearer {genius_api_key}'}
# #             song_url = base_url + song_path
# #             response = requests.get(song_url, headers=headers)
# #             json = response.json()
# #             path = json["response"]["song"]["path"]
# #             page_url = "http://genius.com" + path
# #             page = requests.get(page_url)
# #             html = BeautifulSoup(page.text, "html.parser")
# #             [h.extract() for h in html('script')]
# #             lyrics = html.find("div", class_="lyrics").get_text()
# #             lyrics = lyrics.replace('\n', ' ')
# #             row['lyrics'] = lyrics.lower()

#         #     throw it in the dictionary
# #             songs.append(row)
# #             print(f"Grabbing the lyrics for {song['result']['primary_artist']['name']}, {song['result']['title_with_featured']}")
# Out:
# XXXTENTACION | SAD!
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'}, 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4', 'id': '15UsOTVnJzReFVN1VCnxy4', 'name': 'XXXTENTACION', 'type': 'artist', 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'}, 'href': 'https://api.spotify.com/v1/albums/2Ti79nwTsont5ZHfdxIzAm', 'id': '2Ti79nwTsont5ZHfdxIzAm', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/2e70e7b198acc3bb03aaba9424c5fb23fb38c536', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/4b180600c11e3c89c8b16d6aea3590a5cbfdaea9', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/6924e7074859f79464dd8ddf48455c181df4ce1b', 'width': 64}], 'name': '?', 'release_date': '2018-03-16', 'release_date_precision': 'day', 'total_tracks': 18, 'type': 'album', 'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'}, 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4', 'id': '15UsOTVnJzReFVN1VCnxy4', 'name': 'XXXTENTACION', 'type': 'artist', 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'disc_number': 1, 'duration_ms': 166605, 'explicit': True, 'external_ids': {'isrc': 'USUG11800208'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3ee8Jmje8o58CHK66QrVC2'}, 'href': 'https://api.spotify.com/v1/tracks/3ee8Jmje8o58CHK66QrVC2', 'id': '3ee8Jmje8o58CHK66QrVC2', 'is_local': False, 'name': 'SAD!', 'popularity': 85, 'preview_url': None, 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:3ee8Jmje8o58CHK66QrVC2'}
# XXXTENTACION | Moonlight
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'}, 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4', 'id': '15UsOTVnJzReFVN1VCnxy4', 'name': 'XXXTENTACION', 'type': 'artist', 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'}, 'href': 'https://api.spotify.com/v1/albums/2Ti79nwTsont5ZHfdxIzAm', 'id': '2Ti79nwTsont5ZHfdxIzAm', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/2e70e7b198acc3bb03aaba9424c5fb23fb38c536', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/4b180600c11e3c89c8b16d6aea3590a5cbfdaea9', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/6924e7074859f79464dd8ddf48455c181df4ce1b', 'width': 64}], 'name': '?', 'release_date': '2018-03-16', 'release_date_precision': 'day', 'total_tracks': 18, 'type': 'album', 'uri': 'spotify:album:2Ti79nwTsont5ZHfdxIzAm'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4'}, 'href': 'https://api.spotify.com/v1/artists/15UsOTVnJzReFVN1VCnxy4', 'id': '15UsOTVnJzReFVN1VCnxy4', 'name': 'XXXTENTACION', 'type': 'artist', 'uri': 'spotify:artist:15UsOTVnJzReFVN1VCnxy4'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'disc_number': 1, 'duration_ms': 135090, 'explicit': True, 'external_ids': {'isrc': 'USUG11800209'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/0JP9xo3adEtGSdUEISiszL'}, 'href': 'https://api.spotify.com/v1/tracks/0JP9xo3adEtGSdUEISiszL', 'id': '0JP9xo3adEtGSdUEISiszL', 'is_local': False, 'name': 'Moonlight', 'popularity': 85, 'preview_url': None, 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:0JP9xo3adEtGSdUEISiszL'}

# %%
for song in songs:
    print(song['preview'])
# Out:
# None
# None
# None
# None
# https://p.scdn.co/mp3-preview/bda115bbf4f1de770a9809a2d28dbde92b00b208?cid=de12d73a562343b68e7a6516e08da5fd
# https://p.scdn.co/mp3-preview/bda115bbf4f1de770a9809a2d28dbde92b00b208?cid=de12d73a562343b68e7a6516e08da5fd
# None
# https://p.scdn.co/mp3-preview/8058676c82db42a04ceceb90826af22f7726768a?cid=de12d73a562343b68e7a6516e08da5fd

# %%
# setting up the api search w/ the artist I'm looking for
base_url = "http://api.genius.com"
headers = {'Authorization': f'Bearer {genius_api_key}'}
search_url = base_url + "/search"
artist_name = artist['name']
song_title = song['name']
params = {'q': artist_name}
response = requests.get(search_url, params=params, headers=headers).json()

songs = []
for song in response['response']['hits']:
    song_dict = {}
    
#     getting some of the meta data
    song_dict['artist'] = song['result']['primary_artist']['name']
    song_dict['title'] = song['result']['title_with_featured']
    song_dict['api_path'] = base_url + song['result']['api_path']
    song_dict['album_art'] = song['result']['header_image_url']
    song_dict['lyrics_url'] = base_url + song['result']['path']
    
#  scraping the lyrics
    base_url = "http://api.genius.com"
    song_path = song['result']['api_path']
    headers = {'Authorization': f'Bearer {genius_api_key}'}
    song_url = base_url + song_path
    response = requests.get(song_url, headers=headers)
    json = response.json()
    path = json["response"]["song"]["path"]
    page_url = "http://genius.com" + path
    page = requests.get(page_url)
    html = BeautifulSoup(page.text, "html.parser")
    [h.extract() for h in html('script')]
    lyrics = html.find("div", class_="lyrics").get_text()
    lyrics = lyrics.replace('\n', ' ')
    song_dict['lyrics'] = lyrics.lower()
    
#     throw it in the dictionary
    songs.append(song_dict)
    print(f"Grabbing the lyrics for {song['result']['primary_artist']['name']}, {song['result']['title_with_featured']}")
# Out:
# Grabbing the lyrics for Lil Peep, Star Shopping
# Grabbing the lyrics for Lil Peep & XXXTENTACION, Falling Down
# Grabbing the lyrics for Lil Peep, Save That Shit
# Grabbing the lyrics for Lil Peep, Benz Truck (Гелик)
# Grabbing the lyrics for Lil Peep & Lil Tracy, Witchblades
# Grabbing the lyrics for Lil Peep, Awful Things (Ft. Lil Tracy)
# Grabbing the lyrics for Lil Peep, ​Beamer Boy
# Grabbing the lyrics for Marshmello & Lil Peep, Spotlight
# Grabbing the lyrics for Lil Peep, Crybaby
# Grabbing the lyrics for Lil Peep & Lil Tracy, ​White Wine

# %%
songs_df = pd.DataFrame(songs)
print(songs_df.head(1).lyrics)
songs_df.head(1).lyrics.str.replace('\[\w+: \]','', regex=True)
# Out:
# 0      [intro: shiloh dynasty] i know you so well, so well i mean, i can do anything that he can i've been pretty—  [bridge: xxxtentacion & shiloh dynasty] i know you're somewhere, somewhere i've been trapped in my mind, girl, just holding on i don't wanna pretend we're something, we're nothing i've been stuck thinking 'bout her, i can't hold on (i'll be feeling)  [verse: xxxtentacion] i'm in pain, wanna put ten shots in my brain i've been trippin' 'bout some things, can't change suicidal, same time i'm tame picture this, in bed, get a phone call girl that you fucked with killed herself that was this summer when nobody helped and ever since then, man, i hate myself wanna fuckin' end it, pessimistic all wanna see me with no pot to piss in but niggas been excited 'bout the grave i'm diggin' havin' conversations 'bout my haste decisions fuckin' sickenin'; at the same time memories surface through the grapevine 'bout my uncle playin' with a slip knot post-traumatic stress got me fucked up been fucked up since the couple months they had a nigga locked up  [chorus: xxxtentacion & shiloh dynasty] i'll be feelin' pain, i'll be feelin' pain just to hold on and i don't feel the same, i'm so numb i'll be feelin' pain, i'll be feelin' pain just to hold on and i don't feel the same, i'm so numb  [outro: shiloh dynasty] i know you so well (i know you, girl) i mean, i can do better than he can i've been pretty— i know you so well
# Name: lyrics, dtype: object
# 0      [intro: shiloh dynasty] i know you so well, so well i mean, i can do anything that he can i've been pretty—  [bridge: xxxtentacion & shiloh dynasty] i know you're somewhere, somewhere i've been trapped in my mind, girl, just holding on i don't wanna pretend we're something, we're nothing i've been stuck thinking 'bout her, i can't hold on (i'll be feeling)  [verse: xxxtentacion] i'm in pain, wanna put ten shots in my brain i've been trippin' 'bout some things, can't change suicidal, same time i'm tame picture this, in bed, get a phone call girl that you fucked with killed herself that was this summer when nobody helped and ever since then, man, i hate myself wanna fuckin' end it, pessimistic all wanna see me with no pot to piss in but niggas been excited 'bout the grave i'm diggin' havin' conversations 'bout my haste decisions fuckin' sickenin'; at the same time memories surface through the grapevine 'bout my uncle playin' with a slip knot post-traumatic stress got me fucked up been fucked up since the couple months they had a nigga locked up  [chorus: xxxtentacion & shiloh dynasty] i'll be feelin' pain, i'll be feelin' pain just to hold on and i don't feel the same, i'm so numb i'll be feelin' pain, i'll be feelin' pain just to hold on and i don't feel the same, i'm so numb  [outro: shiloh dynasty] i know you so well (i know you, girl) i mean, i can do better than he can i've been pretty— i know you so well
# Name: lyrics, dtype: object

# %%
for word in emo_df.word:
    if re.findall(word, songs_df.lyrics[0]) != []:
        print(f"{word} shows up {len(re.findall(word, songs_df.lyrics[0]))} time")
# Out:
# art shows up 1 time
# elf shows up 1 time
# fall shows up 2 time
# music shows up 1 time
# rot shows up 1 time
# rot shows up 1 time
# sin shows up 1 time
# sin shows up 1 time
# wan shows up 1 time
# wan shows up 1 time

# %%
songs_df.lyrics.str.replace('\[.+\]', '', regex=True)
# Out:
# 0       Look at the sky tonight, all of the stars have a reason A reason to shine, a reason like mine and I'm fallin' to pieces Look at the sky tonight, all of the stars have a reason
# 1       Come, let's watch the rain as it's falling down Oh-oh-oh, oh-oh, oh-oh Sunlight on your skin when I'm not around, yeah Oh-oh-oh, oh-oh, oh-oh Shit don't feel the same when you're out of town Oh-oh-oh, oh-oh, oh-oh So come, let's watch the rain as it's falling down Oh-oh-oh, oh-oh, oh-oh
# 2       Do I make you scared? Baby, won't you take me back? Nothin' like them other mothafuckas' I can make you rich (I can make you rich)
# 3       Lil Bo Peep with a brand new bitch In the back of the club with the GothBoiClique Iced out teeth on an iced out whip With the limousine tints, you can suck my dick
# 4       Switchblades, cocaine GothBoiClique, make a ho shake Black fur, black coat GothBoiClique in the back, ho Switchblades, cocaine GothBoiClique, 'til my soul take Black jeans, half black hoes GothBoiClique in the castle
# 5       Bother me, tell me awful things You know I love it when you do that Helps me get through this without you Bother me, tell me awful things You know I love it when you move that on me Love it when you do that on me
# 6       Beamer boy
# 7       When the moon hit your skin, I could see you and him Not you and me, yeah It's when you put me in the spotlight (Spotlight) It's when you put me in the spotlight (Spotlight) When the sun shines above, you wake up with the one you love Not you and me, yeah It's when you put me in the spotlight (Spotlight) It's when you put me in the spotlight (Spotlight) (Spotlight, spotlight)
# 8       Oh, it's a lonely world, I know Gon' get a lonely girl, that's fo' sho' Oh, I'm a lonely boy, she made a lonely boy, yeah, I know Oh, it's a lonely world, I know Gon' get a lonely girl, that's fo' sho' Oh, I'm a lonely boy, she made a lonely boy, yeah, I know
# 9       I had no one by my side 'Til this pretty young white bitch hopped up in my ride Took her to the crib and I show her how I die Every night, then I wake up and I'm still fuckin' high Lord why, Lord why do I gotta wake up? More wine, more wine, baby pour another cup Lord why, Lord why do I gotta wake up? More wine, more wine, baby pour another cup Ayo
# Name: lyrics, dtype: object

# %%
songs_df.api_url
# Out:
# 0    http://api.genius.com/songs/2353006
# 1    http://api.genius.com/songs/3906162
# 2    http://api.genius.com/songs/3175124
# 3    http://api.genius.com/songs/3117098
# 4    http://api.genius.com/songs/2977800
# 5    http://api.genius.com/songs/3121880
# 6    http://api.genius.com/songs/2430998
# 7    http://api.genius.com/songs/3384913
# 8    http://api.genius.com/songs/2496168
# 9    http://api.genius.com/songs/2814605
# Name: api_url, dtype: object

# %% [markdown]
# # Trying to get punk songs!

# %%
access_token = os.getenv("SPOTIFY_ACCESS_TOKEN")
token = f"Bearer {access_token}"
base_url = "https://api.spotify.com/v1"
headers = {'Authorization': token}
search_url = "https://api.spotify.com/v1/browse/categories/punk/playlists"

# searching for artists under the emo genre
params = {'limit':50}
response = requests.get(search_url, params=params, headers=headers).json()
response
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/punk/playlists?offset=0&limit=50',
#   'items': [{'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0KpeLFwA3tO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0KpeLFwA3tO',
#     'id': '37i9dQZF1DX0KpeLFwA3tO',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/9634cdb39de83d5bf1c12f9902f43c03779155be',
#       'width': None}],
#     'name': 'New Punk Tracks',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2ODk1MjA2MCwwMDAwMDBlZDAwMDAwMTZkNGNkNDg5MjQwMDAwMDE2ZDRjNzI4Yjc4',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0KpeLFwA3tO/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX0KpeLFwA3tO'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXa9wYJr1oMFq'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXa9wYJr1oMFq',
#     'id': '37i9dQZF1DXa9wYJr1oMFq',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000262822373d6fce52feea1501c',
#       'width': None}],
#     'name': 'Pop Punk Powerhouses',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY5NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXa9wYJr1oMFq/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXa9wYJr1oMFq'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9wa6XirBPv8'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9wa6XirBPv8',
#     'id': '37i9dQZF1DX9wa6XirBPv8',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000205ce83cd2d24bcf721c07630',
#       'width': None}],
#     'name': 'Emo Forever',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY5NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9wa6XirBPv8/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9wa6XirBPv8'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXasneILDRM7B'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXasneILDRM7B',
#     'id': '37i9dQZF1DXasneILDRM7B',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026997d22daeea9df2b8848317',
#       'width': None}],
#     'name': 'Pure Pop Punk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY3OSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXasneILDRM7B/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXasneILDRM7B'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXd6tJtr4qeot'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXd6tJtr4qeot',
#     'id': '37i9dQZF1DXd6tJtr4qeot',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/1f806d54789b35f12dc2afe6240b941ae8b32453',
#       'width': None}],
#     'name': 'Punk Essentials',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY4NywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXd6tJtr4qeot/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXd6tJtr4qeot'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3LDIBRoaCDQ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3LDIBRoaCDQ',
#     'id': '37i9dQZF1DX3LDIBRoaCDQ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000027c704ed09b19a9f3c96b557f',
#       'width': None}],
#     'name': 'Classic Punk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY5NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3LDIBRoaCDQ/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3LDIBRoaCDQ'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1ewVhAJ17m4'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1ewVhAJ17m4',
#     'id': '37i9dQZF1DX1ewVhAJ17m4',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/53c8ce905e4cb47ea436015d762337d8d6b6dda8',
#       'width': None}],
#     'name': "Pop Punk's Not Dead",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY0OCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1ewVhAJ17m4/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1ewVhAJ17m4'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3MU5XUozve7'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3MU5XUozve7',
#     'id': '37i9dQZF1DX3MU5XUozve7',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000021941356cb072eaf2727fa308',
#       'width': None}],
#     'name': 'Skatepark Punks',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY3OCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3MU5XUozve7/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3MU5XUozve7'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBkxDaAQX0a'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBkxDaAQX0a',
#     'id': '37i9dQZF1DXcBkxDaAQX0a',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002f9950283b10663fe5eadf71a',
#       'width': None}],
#     'name': 'Punk Unplugged',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY2OSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBkxDaAQX0a/tracks',
#      'total': 75},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcBkxDaAQX0a'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3YlUroplxjF'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3YlUroplxjF',
#     'id': '37i9dQZF1DX3YlUroplxjF',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/ec191ffaed02d7c4c9f2e858e453a67bc845e419',
#       'width': None}],
#     'name': 'Crash Course',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY5NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3YlUroplxjF/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3YlUroplxjF'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaDzsRodF91I'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaDzsRodF91I',
#     'id': '37i9dQZF1DXaDzsRodF91I',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000029f562efe951b75663cb43fa7',
#       'width': None}],
#     'name': 'Covered In Punk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY3OSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaDzsRodF91I/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXaDzsRodF91I'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7WJ4yDmRK8R'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7WJ4yDmRK8R',
#     'id': '37i9dQZF1DX7WJ4yDmRK8R',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002325ab4a9a33740a667cdff63',
#       'width': None}],
#     'name': 'The Essential Ska',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY4OSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7WJ4yDmRK8R/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX7WJ4yDmRK8R'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXb1IUaS6F7Z8'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb1IUaS6F7Z8',
#     'id': '37i9dQZF1DXb1IUaS6F7Z8',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/1535a00cb40f3e6b165ff2f12cd02064368f6a0f',
#       'width': None}],
#     'name': 'Celtic Punk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY3OCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb1IUaS6F7Z8/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXb1IUaS6F7Z8'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9Mqxt6NLTDY'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9Mqxt6NLTDY',
#     'id': '37i9dQZF1DX9Mqxt6NLTDY',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000027ccfbb91d08604a8b0607158',
#       'width': None}],
#     'name': 'All Things Post',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY4MiwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9Mqxt6NLTDY/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9Mqxt6NLTDY'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1aYJMdIFYsC'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1aYJMdIFYsC',
#     'id': '37i9dQZF1DX1aYJMdIFYsC',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000027169eec83b0c83f3aa9ea7c5',
#       'width': None}],
#     'name': 'Steampunk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY0NywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1aYJMdIFYsC/tracks',
#      'total': 47},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1aYJMdIFYsC'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaGNG7NmtmZv'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaGNG7NmtmZv',
#     'id': '37i9dQZF1DXaGNG7NmtmZv',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002693af7b6870f72b2ffcfcda6',
#       'width': None}],
#     'name': 'Classic Hardcore',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY4NiwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaGNG7NmtmZv/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXaGNG7NmtmZv'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1fmyMdW2PaL'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1fmyMdW2PaL',
#     'id': '37i9dQZF1DX1fmyMdW2PaL',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/19469b80f359671887e010eb2f3f7852b3fa545b',
#       'width': None}],
#     'name': 'Complete Chaos',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY4NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1fmyMdW2PaL/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1fmyMdW2PaL'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdJa941ExayM'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdJa941ExayM',
#     'id': '37i9dQZF1DXdJa941ExayM',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/5a0edc2861ab119a24f961ee3a0e2a1bd6813b9d',
#       'width': None}],
#     'name': 'Punk Unleashed',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY3NiwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdJa941ExayM/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXdJa941ExayM'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWU0FBqUeZYeN'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWU0FBqUeZYeN',
#     'id': '37i9dQZF1DWU0FBqUeZYeN',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002f845977a3d2e97f945fda5b3',
#       'width': None}],
#     'name': 'The Road to Punk Rock',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2ODAyMDUzOSwwMDAwMDAxYzAwMDAwMTZiNmYxNjc1NmUwMDAwMDE2ZDE1NGVhOTlh',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWU0FBqUeZYeN/tracks',
#      'total': 131},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWU0FBqUeZYeN'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXb2cYklA89lm'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb2cYklA89lm',
#     'id': '37i9dQZF1DXb2cYklA89lm',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000021848463d2b7ff32850b3f10b',
#       'width': None}],
#     'name': 'Hot Rods & Horror Shows',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY5NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb2cYklA89lm/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXb2cYklA89lm'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1zG0qRnyaQ3'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1zG0qRnyaQ3',
#     'id': '37i9dQZF1DX1zG0qRnyaQ3',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/adb3d43533dac1499b34758e6142a43086acf8fc',
#       'width': None}],
#     'name': 'Political Punks',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY3OSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1zG0qRnyaQ3/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1zG0qRnyaQ3'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaDPSVSkBhhM'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaDPSVSkBhhM',
#     'id': '37i9dQZF1DXaDPSVSkBhhM',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/a9ce17348596b23b35f9d68b1298df07cf9a0ad7',
#       'width': None}],
#     'name': 'Escena Pop Punk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2OTI4ODY5NCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaDPSVSkBhhM/tracks',
#      'total': 51},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXaDPSVSkBhhM'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7iAOkSHdhFI'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7iAOkSHdhFI',
#     'id': '37i9dQZF1DX7iAOkSHdhFI',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/aba748589ffc7dfaa2982dfd2d45ed695b015d62',
#       'width': None}],
#     'name': 'Green Day: The Early Years',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU0ODc2NTY0MiwwMDAwMDAyODAwMDAwMTYyZDYxMWRlYWQwMDAwMDE2ODk5YTAzZGQ3',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7iAOkSHdhFI/tracks',
#      'total': 29},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX7iAOkSHdhFI'},
#    {'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXbKBGX7pVGFC'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbKBGX7pVGFC',
#     'id': '37i9dQZF1DXbKBGX7pVGFC',
#     'images': [{'height': None,
#       'url': 'https://pl.scdn.co/images/pl/default/babe770126b8c29ee06e6fc9e2700185ef549ce0',
#       'width': None}],
#     'name': 'Grrrls To The Front',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU2NjQxNjE1NywwMDAwMDAwNDAwMDAwMTZjYjVhZGJhN2EwMDAwMDE2YmIzYTI3Yjc2',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbKBGX7pVGFC/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXbKBGX7pVGFC'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 24}}

# %%
access_token = os.getenv("SPOTIFY_ACCESS_TOKEN")
token = f"Bearer {access_token}"
base_url = "https://api.spotify.com/v1"
headers = {'Authorization': token}
search_url = "https://api.spotify.com/v1/browse/categories/punk/playlists" # Right now just looking for punk playlists

params = {'limit':50}
response = requests.get(search_url, params=params, headers=headers).json()

rows = []
for playlist in response['playlists']['items']:
    if playlist['owner']['display_name'] == "Spotify":
        print(playlist['name'])
        
        playlist_response = requests.get(playlist['tracks']['href'],headers=headers).json()
        for song in playlist_response['items']:
            row = {}
            
            row['playlist_name'] = playlist['name']
            row['playlist_link'] = playlist['external_urls']['spotify']
            row['playlist_api'] = playlist['tracks']['href']
            row['song_name'] = song['track']['name']
            row['song_album'] = song['track']['album']['name']
            row['artist_name'] = song['track']['album']['artists'][0]['name']
            row['song_release_date'] = song['track']['album']['release_date'].split("-")[0]
            row['song_length'] = "{:.2f}".format((song['track']['duration_ms'] / 60000))
            row['song_preview'] = song['track']['preview_url']
            row['song_id'] = song['track']['id']
            row['song_explicit'] = song['track']['explicit']
            row['song_popularity'] = song['track']['popularity']
            
            search_url = base_url + "/audio-features/" + song['track']['id']
            response_track_features = requests.get(search_url, headers=headers).json()
            for key in response_track_features.keys():
                row[key] = response_track_features[key]
            
            artist_response = requests.get(song['track']['album']['artists'][0]['href'],headers=headers).json()
            row['artist_genres'] = artist_response['genres']
            row['artist_followers'] = artist_response['followers']['total']
            row['artist_popularity'] = artist_response['popularity']
                
            rows.append(row)
# Out:
# New Punk Tracks
# Pop Punk Powerhouses
# Emo Forever
# Pure Pop Punk
# Punk Essentials
# Classic Punk
# Pop Punk's Not Dead
# Skatepark Punks
# Punk Unplugged
# Crash Course
# Covered In Punk
# The Essential Ska
# Celtic Punk
# All Things Post
# Steampunk
# Classic Hardcore
# Complete Chaos
# Punk Unleashed
# The Road to Punk Rock
# Hot Rods & Horror Shows
# Political Punks
# Escena Pop Punk
# Green Day: The Early Years
# Grrrls To The Front

# %%
df = pd.DataFrame(rows)
df.song_release_date = df.song_release_date.astype(int)
df[(df.valence != 'Nan') & (df.energy != 'Nan') & (df.loudness != 'Nan') & (df.song_popularity != 'Nan')].to_csv('spotify_punk_playlists.csv', index=False)

# %%
df = pd.read_csv('spotify_punk_playlists.csv')

# %%
df[df.song_release_date > 1990].to_csv('spotify_punk_playlists_post90s.csv')

# %%
df.artist_name.value_counts().head(11).index
# Out:
# Index(['Various Artists', 'Green Day', 'Taking Back Sunday', 'Punk Goes',
#        'Neck Deep', 'Bayside', 'Real Friends', 'Trash Boat', 'Seaway',
#        'blink-182', 'Alexisonfire'],
#       dtype='object')

# %%
political_df = df[df.playlist_name == "Political Punks"]
political_df.song_release_date.value_counts().sort_index().plot(title='Songs in the Political Punks playlist')

# %%
playlists_df = pd.DataFrame(df.groupby('artist_name').playlist_name.value_counts()).rename(columns={"playlist_name": 'playlists_in'}).reset_index()

def get_list(x):
    playlists = []
    if x.artist_name == x.artist_name:
        playlists.append(x.playlist_name)
    return playlists

playlists_df.apply(get_list, axis=1)
playlists_df.head()
# Out:
#          artist_name        playlist_name  playlists_in
# 0  25 Ta Life         Classic Hardcore     2
# 1  311                Covered In Punk      1
# 2  7 Year Bitch       Grrrls To The Front  1
# 3  A Day To Remember  Crash Course         1
# 4  A Day To Remember  New Punk Tracks      1

# %%
artist_counts_df = pd.DataFrame(df.groupby('artist_name').playlist_name.nunique().sort_values(ascending=False)).rename(columns={"playlist_name": 'playlists_in'}).reset_index()
artist_counts_df['total'] = df.playlist_name.unique().shape[0]
artist_counts_df['percent_in'] = (artist_counts_df['playlists_in'] / artist_counts_df['total']) * 100
artist_counts_df['genres'] = df.artist_genres
artist_counts_df.genres = artist_counts_df.genres.replace("[\[\]']","", regex=True)
# artist_counts_df.genres = artist_counts_df.genres.str.replace(', ','","')
# artist_counts_df.genres = artist_counts_df.genres.str.replace('^(\w)', '"\\1', regex=True)
# artist_counts_df.genres = artist_counts_df.genres.str.replace('(\w)$', '\\1"', regex=True)
artist_counts_df.head(10).to_csv('artist_counts.csv', index=False)
artist_counts_df.head(10).genres
# Out:
# 0    pop punk, punk, socal pop punk
# 1    anthem emo, pixie, pop emo, pop punk
# 2    alternative emo, dreamo, emo, modern rock, pop punk, post-hardcore, screamo
# 3    metalcore, pop punk, post-screamo, screamo
# 4    punk, ska punk, skate punk
# 5    anthem emo, easycore, melodic hardcore
# 6    canadian folk, canadian pop, electropop, indie poptimism, indietronica
# 7    post-screamo
# 8    canadian punk, hamilton on indie, indie punk
# 9    alternative emo, emo, heartland rock, indie punk, melodic hardcore, modern rock, orgcore, philly indie, pop punk, skate punk
# Name: genres, dtype: object

# %%
def to_list(x):
    return list(x.split(','))

artist_counts_df.head(10).genres.apply(lambda x: to_list(x))
# Out:
# 0    [pop punk, punk, socal pop punk]
# 1    [anthem emo, pixie, pop emo, pop punk]
# 2    [alternative emo, dreamo, emo, modern rock, pop punk, post-hardcore, screamo]
# 3    [metalcore, pop punk, post-screamo, screamo]
# 4    [punk, ska punk, skate punk]
# 5    [anthem emo, easycore, melodic hardcore]
# 6    [canadian folk, canadian pop, electropop, indie poptimism, indietronica]
# 7    [post-screamo]
# 8    [canadian punk, hamilton on indie, indie punk]
# 9    [alternative emo, emo, heartland rock, indie punk, melodic hardcore, modern rock, orgcore, philly indie, pop punk, skate punk]
# Name: genres, dtype: object

# %%
for artist in artist_counts_df.head(10).genres:
#     print(artist)
    print(list(artist.split(',')))
#     new_genres['genre'] = (list(artist.split(',')))
    
pd.DataFrame(new_genres)
# Out:
# ['pop punk', 'punk', 'socal pop punk']
# ['anthem emo', 'pixie', 'pop emo', 'pop punk']
# ['alternative emo', 'dreamo', 'emo', 'modern rock', 'pop punk', 'post-hardcore', 'screamo']
# ['metalcore', 'pop punk', 'post-screamo', 'screamo']
# ['punk', 'ska punk', 'skate punk']
# ['anthem emo', 'easycore', 'melodic hardcore']
# ['canadian folk', 'canadian pop', 'electropop', 'indie poptimism', 'indietronica']
# ['post-screamo']
# ['canadian punk', 'hamilton on indie', 'indie punk']
# ['alternative emo', 'emo', 'heartland rock', 'indie punk', 'melodic hardcore', 'modern rock', 'orgcore', 'philly indie', 'pop punk', 'skate punk']
#               genre
# 0  alternative emo
# 1  emo
# 2  heartland rock
# 3  indie punk
# 4  melodic hardcore
# 5  modern rock
# 6  orgcore
# 7  philly indie
# 8  pop punk
# 9  skate punk

# %%
for playlist in df.artist_name.unique()
# Out:
# array(['blink-182', 'Stand Atlantic', 'Bayside', 'Our Last Night',
#        'Tsunami Bomb', 'Capstan', 'Lights', 'Lonely Avenue',
#        'The Dirty Nil', 'The Menzingers', "Can't Swim", 'Mudhoney',
#        'Belmont', 'Tiny Stills', 'Summer Heights',
#        'Ready Steady Steroids', 'Waco', 'Misery Loves Company', 'Snuff',
#        'Tiny Moving Parts', 'Green Day', 'Fall Out Boy', 'Raised Fist',
#        'Microwave', 'Refused', 'Waterparks', 'Agnostic Front', 'WSTR',
#        'Sleep On It', 'Tiger Army', 'Mest', 'Touché Amoré',
#        'Boys of Fall', 'Pixies', 'Chastity', 'Assuming We Survive',
#        'Cursive', 'Deez Nuts', 'MakeWar', 'Storyteller',
#        'The Anti-Queens', 'Locket', 'Alone I Walk', 'These Five Years',
#        'Not Ur Girlfrenz', 'Drakulas', 'Bony Macaroni', 'Subhumans',
#        'Bob Mould', 'Avoid One Thing', 'Spermbirds', 'Wayfarer', 'ROAM',
#        'Sleeping With Sirens', 'Teenage Bottlerocket', 'Lagwagon',
#        'Grayscale', 'Gideon', 'Iggy Pop', 'Senses Fail',
#        'The Early November', 'Hail The Sun', 'Spielbergs', 'Third Season',
#        'Higher Power', 'Mobina Galore', 'Bearings', 'The Penske File',
#        'Spring.Fall.Sea', 'Roxy Girls', 'Western Settings', 'The Run Up',
#        'Angels & Airwaves', 'Counterparts', 'Trash Boat',
#        'Simple Creatures', 'Rarity', 'The Lungs', 'DZ Deathrays',
#        'Mean Jeans', 'Near Mint', 'Thousand Below', 'The Decline',
#        'The Bottom Line', 'Jones the Cat', 'Sixteen Scandals', 'Somos',
#        'Lightweights', 'Audio Karate', 'Graduating Life', 'Real Sickies',
#        'The Carolyn', 'A Day To Remember', 'Taking Back Sunday',
#        'Mayday Parade', 'Sugarcult', 'Jimmy Eat World',
#        'My Chemical Romance', 'New Found Glory', 'Yellowcard',
#        'Panic! At The Disco', 'All Time Low', 'Lit',
#        'The All-American Rejects', 'AFI', 'Story Of The Year',
#        'Good Charlotte', 'Relient K', 'Sum 41', 'Paramore',
#        'The Red Jumpsuit Apparatus', 'Rise Against', 'We The Kings',
#        'Bowling For Soup', 'Simple Plan', 'Fountains Of Wayne',
#        'The Ataris', 'The Offspring', 'Lustra', 'Dear and the Headlights',
#        'Dance Gavin Dance', 'Circa Survive', 'mewithoutYou', 'Brand New',
#        'Thursday', 'Saosin', 'Alkaline Trio', 'Hawthorne Heights',
#        'Armor For Sleep', 'Chiodos', 'The Fall of Troy',
#        'Various Artists', 'Alexisonfire', 'Underoath', 'The Used',
#        'Valencia', 'Say Anything', 'The Dangerous Summer', 'Thrice',
#        'Saves The Day', 'From First To Last', 'Halifax', 'Mae',
#        'The Audition', 'Finch', 'Cute Is What We Aim For', 'Moose Blood',
#        'Boston Manor', 'The Wonder Years', 'Real Friends', 'Knuckle Puck',
#        'Neck Deep', 'The Story So Far', 'Like Pacific', 'Homebound',
#        'Trophy Eyes', 'Between You & Me', 'Silverstein', 'Crooked Teeth',
#        'We Were Sharks', 'Broadside', 'The Gospel Youth',
#        'With Confidence', 'Seaway', 'The Maine', 'Four Year Strong',
#        'Hot Milk', 'State Champs', 'Propagandhi', 'Heavens', 'Samiam',
#        'Streetlight Manifesto', 'H2O', 'Strike Anywhere', 'Jawbreaker',
#        'The Get Up Kids', 'The Bollweevils', 'Deviates',
#        'Motion City Soundtrack', 'The Bronx', 'The Suicide Machines',
#        'Off With Their Heads', 'Assorted Jelly Beans', 'Counterpunch',
#        'Mustard Plug', 'Descendents', 'Hot Water Music', 'The Flatliners',
#        'Me First and the Gimme Gimmes', 'The Dead Milkmen', 'Dag Nasty',
#        'Germs', 'Agent Orange', 'Fugazi', 'Joy Division', 'Bad Brains',
#        'Circle Jerks', 'Minor Threat', 'Hüsker Dü', 'GBH', 'Black Flag',
#        'Beastie Boys', 'Minutemen', 'Wire', 'T.S.O.L.', 'Operation Ivy',
#        'D.O.A.', 'Suicidal Tendencies', 'Misfits', 'Bad Religion',
#        'Reagan Youth', 'The Vandals', 'DEVO', 'Fear', 'Adolescents',
#        'Dead Kennedys', 'Gang Of Four', 'Buzzcocks', 'Dead Boys', 'X',
#        'The Damned', 'Free Throw', 'Wilmette', 'Homesafe',
#        'In Her Own Words', 'Romancer', 'Northbound', 'Youth Fountain',
#        'Bearclaw Camp', 'Gold Route', 'Penelope Tree',
#        'Calling All Captains', 'Stickup Kid', 'Honey Creek', 'Calmgrove',
#        'The Home Team', 'Point North', 'Such Luck', 'Carousel Kings',
#        'Fluorescents', 'Eat Your Heart Out', 'House Fight',
#        'Nothing Serious', 'Castlefield', 'One Up', 'Weatherstate',
#        'Stuck Out', 'Internet Friends', 'WRTHLESS', 'Meet Me @ The Altar',
#        'Plans', 'Headstrong', 'Chief State', 'Arcane Ghosts',
#        'Second Harbour', 'Much The Same', 'Telltale', 'Bounds of Modesty',
#        'Hello Violet', 'Incase We Crash', 'Victory Lane', 'PNKR',
#        'Stay up Late', 'Get Your Head Straight', 'Sundressed',
#        'Certainty', 'PUP', 'Napoleon', 'Such Gold', 'Pet Symmetry',
#        'Bracket', 'Coming Clean', 'Clowns', 'Thousand Oaks',
#        'Jeff Rosenstock', 'RAT BOY', 'Fights And Fires',
#        'Russian Girlfriends', 'Rehasher', 'Strung Out', 'Brookhurst',
#        'Math The Band', 'Build Them To Break',
#        'Frank Carter & The Rattlesnakes', 'Radkey', 'BOTTLEKIDS',
#        'Long Story Short', 'Tear Them Down', 'The Evaporators',
#        'Out of My Way', 'The Besmirchers', 'Direct Hit!',
#        'The Car Bomb Parade', 'Charlatan', 'Lovesick Bombs',
#        'Good Riddance', 'Babe Patrol', 'Cold Wrecks', 'Death By Horse',
#        'March', 'Grade 2', 'Blood Command', 'Veara', 'Title Fight',
#        'The Copyrights', 'Primetime Failure', 'The ProblemAddictsfl',
#        'zebrahead', 'The Lucky Eejits', 'Leftöver Crack', 'Life Lessons',
#        'Dinosaur Pile-Up', 'The Dollyrots', 'Authority Zero',
#        'Protagonist', 'Punk Goes', 'Bogues', 'Roseview', 'Cory Wells',
#        'Pierce The Veil', 'Go For Gold', 'Headspace',
#        'Atlantic Wasteland', 'Heavy Things', 'William Ryan Key',
#        'Oh, Weatherly', 'Letdown', 'Shorelines', 'Driveways',
#        'Ten Foot Pole', 'The Wildhood', 'Mike Herrera', 'MariaHill',
#        'AS IT IS', 'FigureItOut', 'Slaves', 'Millington', 'SayWeCanFly',
#        'Summer Wars', 'Sink or Swim', 'Another One Down!', 'Beartooth',
#        'Bilmuri', 'Wolf & Bear', 'Fake a Home', 'Bloom', 'Nicolas Rage',
#        'Mayfield', 'Vagrants', 'Capsize', 'Harm', 'Holding Absence',
#        'Acres', 'Dragged Under', "Moderntears'", 'Comrades',
#        'CrazyEightyEight', 'fairwell', 'As Cities Burn',
#        'We Never Learned To Live', 'Rival Town', 'To Octavia',
#        'Parting Gift', 'Lilac Kings', 'Picturesque', 'Jack the Envious',
#        'Vanish', 'Dead Lakes', 'Conversation', 'NU-95', 'Arc of the Sun',
#        'Glass Tides', 'Osatia', 'Glorious Failure', 'Crown The Empire',
#        'Dream State', 'Painting Promises', 'The March Ahead',
#        'Speech Patterns', 'Outline In Color', 'Friday Giants',
#        'The Funeral Portrait', 'IMMERSE', 'Get Scared', 'No Eden',
#        'VRSTY', 'City Kids Feel The Beat', 'Secret Eyes',
#        'Famous Last Words', 'Bad/Love', 'Chin Up, Kid', 'Denzel Curry',
#        'Cancer Bats', 'Save Face', 'MxPx', 'Angry Youth Elite',
#        'Sincerely, Me', 'The Regrettes', 'Ballyhoo!', 'Colour & Shade',
#        '311', 'Awake At Last', 'Abandoned By Bears', 'The Frights',
#        'We Are The Union', 'Codename Colin', 'Tropidelic', 'Rude Tins',
#        'Stacked Like Pancakes', 'Rx Bandits', 'Kill Lincoln',
#        'Bumpin Uglies', 'Buck-O-Nine', 'King Prawn',
#        'The Planet Smashers', 'K-Man & The 45s', 'Backyard Superheroes',
#        'Russkaja', 'Anti-Flag', 'The Specials', 'Against All Authority',
#        'Popes Of Chillitown', 'Reel Big Fish', 'Left Alone',
#        'Bomb the Music Industry!', 'The Bar Stool Preachers',
#        'The Mighty Mighty Bosstones', 'The Supervillains',
#        'South Central Skankers', 'Goldfinger', 'Jaya The Cat',
#        'Save Ferris', "Cherry Poppin' Daddies", 'The Interrupters',
#        'Catch 22', 'Less Than Jake', 'Starfish',
#        'Big D and the Kids Table', 'The Slackers', 'NOFX',
#        'Voodoo Glow Skulls', 'The Aquabats!', 'Sublime',
#        'Accidental President', 'Mad Caddies', 'Random Hand', 'Rancid',
#        'Sonic Boom Six', 'The Hippos', 'Capdown', 'The Pietasters',
#        '[spunge]', "Skankin' Pickle", 'Millencolin',
#        'Dance Hall Crashers', 'Five Iron Frenzy', 'Larry and His Flask',
#        'The Walker Roaders', 'Brave the Sea', 'North Alone',
#        'Pipes And Pints', 'The Rumjacks', "Fiddler's Green",
#        'Paddy And The Rats', 'The Gobshites', 'The Rumpled',
#        'Irish Moutarde', 'The Stanfields', 'The Killigans', 'Sir Reg',
#        'The Roughneck Riot', 'Firkin', 'The Dreadnoughts',
#        'Smokey Bastard', "Happy Ol'McWeasel", 'The Bollox',
#        'Brick Top Blaggers', 'The Peelers',
#        "The O'Reillys and the Paddyhats", 'Bastard Bearded Irishmen',
#        'Flogging Molly', "Saint Bushmill's Choir", 'The Wages of Sin',
#        'The Real McKenzies', 'Black Tartan Clan', 'Jolly Jackers',
#        'The Bloody Irish Boys', 'Blaggards', 'The Porters',
#        'The American Wake', 'The Kreellers', 'Flatfoot 56',
#        'The Mighty Regis', 'The Tossers', 'Dropkick Murphys',
#        'La Dispute', 'I The Mighty', 'find yourself', 'Basement',
#        'Gatherers', 'The Kodiak', 'All Get Out', 'Household',
#        'The Drowned God', 'Tapestry', 'Hundredth', 'Emery',
#        'Pianos Become The Teeth', 'Hippie Trim', 'Chiefland', 'Pile',
#        'Citizen', 'Bars of Gold', 'Good Tiger', 'Silent Majority',
#        'Introvert', 'Joyce Manor', 'Glassjaw', 'Hotel Books', 'Vattnet',
#        'Brutus', 'Dead To Me', 'Heavy Hearts', 'Flèche',
#        'The World Is A Beautiful Place & I Am No Longer Afraid To Die',
#        'DILLY DALLY', 'Trans Am', 'Shell of a Shell', 'Quicksand',
#        'violet night', 'Rites of Spring', 'Metz', 'Soviet Soviet',
#        'Fucked Up', 'Desaparecidos', 'Ghum', 'INVSN', 'The Beta Machine',
#        'Protomartyr', 'Twin Peaks', 'Royal Headache', 'Shame', 'Jawbox',
#        'Pissed Jeans', 'The Blood Brothers', 'Hooray For Earth', 'FIDLAR',
#        'And So I Watch You from Afar', 'At The Drive In', 'Jay Munly',
#        'Sophe Lux', 'Pretty Balanced', 'This Way To The Egress',
#        'The Mechanisms', 'Dave Sixx', 'Palko!Muski', 'Josh Whitehouse',
#        'Vernian Process', 'The Peculiar Pretzelmen', 'Reverend Glasseye',
#        'Unextraordinary Gentlemen', 'Sunday Driver', 'The Dresden Dolls',
#        'The Jane Austen Argument', 'Steam Powered Giraffe',
#        'Mr.B The Gentleman Rhymer',
#        'The Men That Will Not Be Blamed For Nothing', 'Copal',
#        'Clare Fader', 'Aurelio Voltaire', 'Professor Elemental',
#        'The Cog is Dead', 'Frenchy and the Punk',
#        "Emperor Norton's Stationary Marching Band", 'Scarlet Room',
#        'Emilie Autumn', 'Escape the Clouds', 'Abney Park',
#        'The Dead Brothers', 'Beat Circus', 'KK & The Steampunk Orchestra',
#        'Ghostfire', 'The Electro Swingers', 'The Dirt Daubers',
#        'Jill Tracy', 'The Hope Conspiracy', 'Indecision', 'Endicott',
#        'Bane', 'Candiria', 'Stigmata', 'Earth Crisis', 'Sheer Terror',
#        'One King Down', 'Shutdown', 'Kill Your Idols', 'All Out War',
#        'Gorilla Biscuits', 'Terror', 'Most Precious Blood', 'Snapcase',
#        'Warzone', 'Youth Of Today', 'Cro-Mags', 'CIV', 'Comeback Kid',
#        'Western Addiction', 'Strife', '25 Ta Life', 'Wisdom In Chains',
#        'First Blood', 'Vision Of Disorder', 'Death By Stereo',
#        'Sworn Enemy', 'Death Before Dishonor', 'Downset',
#        'Sick Of It All', 'Defeater', 'Knocked Loose', 'Dead Tired',
#        'Sanction', 'Have Heart', 'Amygdala', 'Hesitation Wounds',
#        'The Pariah', 'Last Hounds', 'State Faults', 'Castaway',
#        'Pressure Cracks', 'The Threats', 'Lock & Key',
#        'Death of a Nation', 'No Home', 'Vein', 'We Too, Will Fade',
#        'Rotting Out', 'Turnstile', 'Jesus Piece', 'Varials', 'Kharma',
#        'Dispeller', 'The Armed', 'Inclination', 'To Kill', 'Ghost Chant',
#        'Boundaries', 'We Struck Gold', 'SET SIGHTS', 'Ratking',
#        'The Good Depression', 'Crafter', 'Liberties', 'Incendiary',
#        'Fury', 'Lifesick', 'The Danger Of Falling', 'Ass Life',
#        'Reclaimer', 'Chokehold', 'Exemption', 'Single Wound',
#        'Will To Die', 'COPE', 'Sudden Waves', 'Modern Life Is War',
#        'Judiciary', 'Lawless Sons', 'Great Grief', 'Trail of Lies',
#        'Born Free', 'Bent Life', 'Heart Attack Kids', 'Backtrack',
#        'Staredown', 'SICK MINDS', 'Frontside', 'Expire', 'Wake The Dead',
#        'Erabella', 'Purgatory', 'Iron Reagan', 'Primitive Weapons',
#        'Remo Drive', 'Prince Daddy & the Hyena', 'Origami Angel',
#        'Culture Abuse', 'Angel Du$t', 'The Front Bottoms',
#        'Aaron West and The Roaring Twenties', 'Heart Attack Man',
#        'Bonsai Trees', 'Drug Church', 'Unturned', 'The Sonder Bombs',
#        'Arcadia Grey', 'Ceremony', 'Bad Luck', 'Holding Patterns', 'PINE',
#        'Ariel View', 'Spanish Love Songs', 'America Part Two', 'Grayling',
#        'Halogens', 'Single Mothers', 'Locals Only', 'Oso Oso',
#        'Mom Jeans.', 'Signals Midwest', 'Spectral Fires',
#        'Rome Hero Foxes', 'The Sidekicks', 'DEAR-GOD',
#        'The Drew Thomson Foundation', 'Antarctigo Vespucci', 'Billy Cobb',
#        'Blessed', 'Never Loved', 'Downhaul', 'The 1975', 'Sammi Lanzetta',
#        'Big Nothing', 'Decent Criminal', 'McCafferty', 'GoldTop',
#        'Petrol Girls', 'Plague Vendor', 'Barely March', 'Vacation',
#        'Nightmarathons', 'Kitty Kat Fan Club', 'Luke Seymoup', 'Squidge',
#        'Re-Volts', 'Sik Oheso', 'Skating Polly', 'Fresh',
#        'Otoboke Beaver', 'Telethon', 'Pkew Pkew Pkew', 'The Kinks',
#        'New York Dolls', 'MC5', 'The Sonics', 'The Cramps', 'The Clash',
#        'The Who', 'Patti Smith', 'Shocking Blue', 'The Third Bardo',
#        'Love', 'Van Morrison', 'Lou Reed', 'The Velvet Underground',
#        'Black Sabbath', 'David Bowie', 'NEU!', 'Peter Hammill', 'Ramones',
#        'The Monks', 'The Rolling Stones', 'Little Richard', 'The Byrds',
#        'The Creation', 'Loretta Lynn', 'Count Five', 'Steve Winwood',
#        'The Wailers', 'Moving Sidewalks & The Coachmen',
#        'The 13th Floor Elevators', 'The Rugbys', 'The Electric Prunes',
#        "Rockin' Ramrods", 'The Turtles', 'The Dictators', 'The Seeds',
#        'Link Wray', 'Alice Cooper', 'Jimi Hendrix', 'Urinals',
#        'Brian Eno', 'The Easybeats', 'The Pink Fairies', 'The Remains',
#        'Mott The Hoople', 'Jack Starr', 'Edgar Broughton Band',
#        'The Stooges', 'Hasil Adkins',
#        "Johnny Burnette & The Rock 'N' Roll Trio", 'Amon Düül II',
#        'David Peel and The Lower East Side', "Flamin' Groovies",
#        'The Groundhogs', 'Roxy Music', 'The Controllers', 'The Residents',
#        'John Cale', 'Silver Apples', 'The Deviants',
#        'The Sensational Alex Harvey Band', 'Kilburn & The High Roads',
#        'Sparks', 'Suicide', 'Rocket From The Tombs', 'Television',
#        'Miss Vincent', 'Bloodsucking Zombies from outer Space',
#        'Twilight Creeps', 'Drunktank', 'Bullet Machine', 'The Rosedales',
#        'The Atom Age', 'Sarah and the Safe Word', 'Kepi Ghoulie',
#        'Horror Section', 'Stellar Corpses', 'The Crimson Ghosts',
#        'Wednesday 13', 'Toxic Zombie', 'The Other', 'Gutter Demons',
#        'The Buttertones', 'Koffin Kats', 'The Three Sum', 'The Creepshow',
#        'Calabrese', 'The Arkhams', 'The Living End', 'Stray Cats',
#        'The Reverend Horton Heat', 'Mad Sin', 'The Brains',
#        'Demented Are Go', 'Nekromantix', 'Batmobile', 'Horrorpops',
#        'Riskee & The Ridicule', 'Antillectual', 'FEVER 333', 'Clarkkent',
#        'A Vulture Wake', 'Debt Neglector', 'The Hunting Project',
#        'Drones', 'KillRadio', 'Great Collapse', 'Total Massacre',
#        'Templeton Pek', 'Pennywise', 'U.S. Bombs', 'Street Dogs',
#        'Bad Cop, Bad Cop', 'Boysetsfire', 'Joe Strummer', 'Camiches',
#        'Sad Saturno', 'Sureste', 'Barney Gombo', 'May Sunday', 'INSITE',
#        'Mi Mascota Leila', 'Levigne', 'DON', 'Traits', 'Say Ocean',
#        'Tungas', 'Sullivan', 'Diez Veces Yo', 'Corre Forrest!',
#        'Chingadazo de Kung Fu', 'Amsterdam', 'Nose!', 'Andrés Canalla',
#        'Nuno', 'Venner', 'Delux', 'Da Skate', 'Aurum', 'Abril 88',
#        'Skates Mx', 'Primo', 'TMP', 'División Minúscula', 'Novella Inc',
#        'Buen Viaje', 'Infalibles', 'Masappan', 'Corvje', 'Hey Bésala',
#        'Finde', 'Allison', 'Spotify Originals', 'Bratmobile', 'The Gits',
#        'X-Ray Spex', 'Excuse 17', '7 Year Bitch', 'The Slits',
#        "Emily's Sassy Lime", 'Autoclave', 'Sleater-Kinney',
#        'Cold Cold Hearts', 'Veruca Salt', 'L7', 'Hole',
#        'Heavens To Betsy', 'Huggy Bear', 'Le Tigre', 'Gossip',
#        'Babes In Toyland\xa0', 'Bikini Kill', 'Lunachicks', 'Slant 6',
#        'Perfect Pussy', 'PJ Harvey', 'The Runaways', 'Delta 5',
#        'The Julie Ruin', 'Bush Tetras', 'Pussy Riot', 'Savages',
#        'Lungleg', 'Skinned Teen', 'Peaches', 'Screaming Females',
#        'The Raincoats'], dtype=object)

# %%
df.artist_name.value_counts().
# Out:
# Various Artists                 42
# Green Day                       22
# Taking Back Sunday              14
# Punk Goes                       12
# Neck Deep                       10
# Real Friends                    9
# Trash Boat                      9
# Bayside                         9
# blink-182                       8
# Alexisonfire                    8
# Seaway                          8
# Stand Atlantic                  7
# Thursday                        7
# The Story So Far                7
# Silverstein                     7
# WSTR                            7
# The Dangerous Summer            6
# Point North                     6
# Senses Fail                     6
# Good Riddance                   6
# Tiger Army                      6
# Tiny Moving Parts               6
# Misfits                         6
# Moose Blood                     6
# PUP                             6
# The Menzingers                  6
# Underoath                       6
# ROAM                            6
# H2O                             5
# My Chemical Romance             5
#                                ..
# Le Tigre                        1
# Incendiary                      1
# Steam Powered Giraffe           1
# Wayfarer                        1
# Link Wray                       1
# Judiciary                       1
# The Gobshites                   1
# K-Man & The 45s                 1
# The Penske File                 1
# Finde                           1
# The Vandals                     1
# The Besmirchers                 1
# Letdown                         1
# Primitive Weapons               1
# Not Ur Girlfrenz                1
# Pissed Jeans                    1
# NEU!                            1
# KillRadio                       1
# Bomb the Music Industry!        1
# Jay Munly                       1
# KK & The Steampunk Orchestra    1
# find yourself                   1
# Pkew Pkew Pkew                  1
# Copal                           1
# Sink or Swim                    1
# The Copyrights                  1
# We Too, Will Fade               1
# Sugarcult                       1
# Oso Oso                         1
# Joe Strummer                    1
# Name: artist_name, Length: 927, dtype: int64

# %%
plt.style.use('fivethirtyeight')
df.groupby('song_release_date').energy.mean().plot()

# %%
plt.style.use('fivethirtyeight')
df.groupby('song_release_date').valence.mean().plot()

# %%
df.song_release_date.hist()

# %%
recent_df = df[df.song_release_date > 2017]

# %%
recent_df.keys()
# Out:
# Index(['acousticness', 'analysis_url', 'artist_followers', 'artist_genres',
#        'artist_name', 'artist_popularity', 'danceability', 'duration_ms',
#        'energy', 'error', 'id', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'playlist_api', 'playlist_link', 'playlist_name',
#        'song_album', 'song_explicit', 'song_id', 'song_length', 'song_name',
#        'song_popularity', 'song_preview', 'song_release_date', 'speechiness',
#        'tempo', 'time_signature', 'track_href', 'type', 'uri', 'valence'],
#       dtype='object')

# %%
source = recent_df

alt.Chart(source).mark_point().encode(
    x='valence',
    y='energy',
    color='song_explicit',
#     size='loudness'
)

# %%
alt.Chart(pd.DataFrame(df.groupby('song_release_date').energy.mean()).reset_index()).mark_line().encode(
    x='song_release_date',
    y='energy'
)

# %%
pd.DataFrame(df.groupby('song_release_date').energy.mean()).reset_index()
# Out:
#    song_release_date    energy
# 0   1964              0.694500
# 1   1965              0.924000
# 2   1966              0.770857
# 3   1967              0.567200
# 4   1968              0.936500
# 5   1969              0.511667
# 6   1970              0.659857
# 7   1971              0.505692
# 8   1972              0.697800
# 9   1973              0.619091
# 10  1974              0.733600
# 11  1975              0.556300
# 12  1976              0.768538
# 13  1977              0.627353
# 14  1978              0.755714
# 15  1979              0.745815
# 16  1980              0.772875
# 17  1981              0.751450
# 18  1982              0.842308
# 19  1983              0.842000
# 20  1984              0.824500
# 21  1985              0.751300
# 22  1986              0.766786
# 23  1987              0.879167
# 24  1988              0.754875
# 25  1989              0.822333
# 26  1990              0.839600
# 27  1991              0.831000
# 28  1992              0.829500
# 29  1993              0.794500
# 30  1994              0.794500
# 31  1995              0.870833
# 32  1996              0.896286
# 33  1997              0.885818
# 34  1998              0.904857
# 35  1999              0.908667
# 36  2000              0.841167
# 37  2001              0.857385
# 38  2002              0.892286
# 39  2003              0.888680
# 40  2004              0.911950
# 41  2005              0.892588
# 42  2006              0.871154
# 43  2007              0.874667
# 44  2008              0.896000
# 45  2009              0.893200
# 46  2010              0.892433
# 47  2011              0.904056
# 48  2012              0.787455
# 49  2013              0.828581
# 50  2014              0.872435
# 51  2015              0.953367
# 52  2016              0.889854
# 53  2017              0.891959
# 54  2018              0.852491
# 55  2019              0.879955
