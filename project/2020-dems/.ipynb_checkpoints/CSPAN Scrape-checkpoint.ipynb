# %% [markdown]
# # C-SPAN Tracker
# Grabbing candidate info from their C-SPAN pages
# <hr>

# %% [markdown]
# ## Importing modules

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
from selenium import webdriver
import datetime as dt  
import numpy as np
from dotenv import load_dotenv
load_dotenv()
import os
import json

api_key = os.getenv("GMAP_API")
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
import seaborn as sns

# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Booting up BeautifulSoup
# Grabbing candidate information from the Road to the White House Candidates page

# %%
response = requests.get("https://www.c-span.org/series/?roadToTheWhiteHouse#candidates-tab")
doc = BeautifulSoup(response.text)

# %%
## Zoning in on the running Democratic candidates
dems = doc.find("ul", class_="candidate-list").find_all("li", class_="D")
len(dems)
# Out:
# 23

# %%
# All the info from the all-candidate page

rows = []

for dem in dems:
    row = {}
    row['Name'] = dem.find(class_="candidate D").text.strip()
    row['Announce Date'] = dem.find(class_="datetime").text.strip()
    row['Bio'] = dem.find(class_="candidate D")["href"]
    try:
        row['Slug'] = dem.find(class_="candidate-links").find_all("a")[1]['href']
    except: pass
    
    rows.append(row)

# rows

# %%
df = pd.DataFrame(rows, columns=["Name", "Slug", "Announce Date", "Bio"])

# %%
df.Bio = df.Bio.astype(str)
df.Bio
# Out:
# 0          //www.c-span.org/person/?michaelbennet
# 1            //www.c-span.org/person/?josephbiden
# 2             //www.c-span.org/person/?corybooker
# 3         //www.c-span.org/person/?stevebullock02
# 4          //www.c-span.org/person/?petebuttigieg
# 5           //www.c-span.org/person/?juliancastro
# 6          //www.c-span.org/person/?johndelaney02
# 7           //www.c-span.org/person/?tulsigabbard
# 8      //www.c-span.org/person/?kirstengillibrand
# 9           //www.c-span.org/person/?kamalaharris
# 10     //www.c-span.org/person/?johnwhickenlooper
# 11             //www.c-span.org/person/?jayinslee
# 12          //www.c-span.org/person/?amyklobuchar
# 13           //www.c-span.org/person/?sethmoulton
# 14           //www.c-span.org/person/?betoorourke
# 15             //www.c-span.org/person/?timryan03
# 16         //www.c-span.org/person/?berniesanders
# 17          //www.c-span.org/person/?josephsestak
# 18          //www.c-span.org/person/?ericswalwell
# 19       //www.c-span.org/person/?elizabethwarren
# 20    //www.c-span.org/person/?mariannewilliamson
# 21            //www.c-span.org/person/?andrewyang
# 22          //www.c-span.org/person/?billdeblasio
# Name: Bio, dtype: object

# %% [markdown]
# ## Cleaning it up a bit

# %%
df["Announce Date"] = df["Announce Date"].str.extract(":\s(.*)")
df['Slug'] = df['Slug'].str.extract("(personid.*)")
df['Bio'] = df['Bio'].str.extract("\?(.*)")

# %%
df.Bio.astype(str)
# Out:
# 0          michaelbennet
# 1            josephbiden
# 2             corybooker
# 3         stevebullock02
# 4          petebuttigieg
# 5           juliancastro
# 6          johndelaney02
# 7           tulsigabbard
# 8      kirstengillibrand
# 9           kamalaharris
# 10     johnwhickenlooper
# 11             jayinslee
# 12          amyklobuchar
# 13           sethmoulton
# 14           betoorourke
# 15             timryan03
# 16         berniesanders
# 17          josephsestak
# 18          ericswalwell
# 19       elizabethwarren
# 20    mariannewilliamson
# 21            andrewyang
# 22          billdeblasio
# Name: Bio, dtype: object

# %%
df.iloc[17,1] = "personid[]=1020918"

# %% [markdown]
# ## Getting the date's formatted correctly

# %%
df['Announce Date'] = pd.to_datetime(df['Announce Date'], format="%B %d, %Y", errors='coerce')
df['Announce Date'] = df['Announce Date'].dt.strftime("%m/%d/%Y")

# %% [markdown]
# ## Scraping the bio pages

# %%
def scrape_bio(row):
    regexp = re.compile(r'http://bioguide.*')
    url = "https://www.c-span.org/person/?" + row["Bio"]
    
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    for li in doc.find_all("li"):
        li.decompose()
    doc.find('footer').decompose()
    profile = doc.find(id="content")
    
    ## Print out the slug column
    print("Scraping", url)
    
    bio = {}

    bio['Name'] = profile.find('h1').text.strip()
    bio['IMG'] = profile.find('img')['src']
    bio['Official Bio'] = profile.find(href=regexp)
    
    bio['Description'] = []
    for desc in profile.find_all(itemprop="description"):
        bio['Description'].append(desc.text.strip())
    
    bio['Titles'] = []
    for titles in doc.find_all('span', class_=['title']):
        bio['Titles'].append(titles.text.strip())
    
    return pd.Series(bio)

# %%
bio_df = df.apply(scrape_bio, axis=1)
# Out:
# Scraping https://www.c-span.org/person/?michaelbennet
# Scraping https://www.c-span.org/person/?michaelbennet
# Scraping https://www.c-span.org/person/?josephbiden
# Scraping https://www.c-span.org/person/?corybooker
# Scraping https://www.c-span.org/person/?stevebullock02
# Scraping https://www.c-span.org/person/?petebuttigieg
# Scraping https://www.c-span.org/person/?juliancastro
# Scraping https://www.c-span.org/person/?johndelaney02
# Scraping https://www.c-span.org/person/?tulsigabbard
# Scraping https://www.c-span.org/person/?kirstengillibrand
# Scraping https://www.c-span.org/person/?kamalaharris
# Scraping https://www.c-span.org/person/?johnwhickenlooper
# Scraping https://www.c-span.org/person/?jayinslee
# Scraping https://www.c-span.org/person/?amyklobuchar
# Scraping https://www.c-span.org/person/?sethmoulton
# Scraping https://www.c-span.org/person/?betoorourke
# Scraping https://www.c-span.org/person/?timryan03
# Scraping https://www.c-span.org/person/?berniesanders
# Scraping https://www.c-span.org/person/?josephsestak
# Scraping https://www.c-span.org/person/?ericswalwell
# Scraping https://www.c-span.org/person/?elizabethwarren
# Scraping https://www.c-span.org/person/?mariannewilliamson
# Scraping https://www.c-span.org/person/?andrewyang
# Scraping https://www.c-span.org/person/?billdeblasio

# %%
bio_df.to_csv("candidate_info.csv", index=False)

# %%
bio_df
# Out:
#                      Name                                                IMG  \
# 0          Michael Bennet  https://images.c-span.org/Files/6de/2019062300...
# 1           Joe Biden Jr.  https://images.c-span.org/Files/993/2019062423...
# 2             Cory Booker  https://images.c-span.org/Files/dbe/2019062423...
# 3           Steve Bullock  https://images.c-span.org/Files/ff2/2019051721...
# 4          Pete Buttigieg  https://images.c-span.org/Files/e28/2019062221...
# 5           Julian Castro  https://images.c-span.org/Files/fc6/2019062222...
# 6         John K. Delaney  https://images.c-span.org/Files/26c/2019062222...
# 7           Tulsi Gabbard  https://images.c-span.org/Files/793/2019062913...
# 8   Kirsten E. Gillibrand  https://images.c-span.org/Files/991/2019062220...
# 9        Kamala D. Harris  https://images.c-span.org/Files/e2a/2019062421...
# 10   John W. Hickenlooper  https://images.c-span.org/Files/ee0/2019062220...
# 11             Jay Inslee  https://images.c-span.org/Files/f79/2019062422...
# 12          Amy Klobuchar  https://images.c-span.org/Files/a20/2019070123...
# 13        Seth W. Moulton  https://images.c-span.org/Files/608/2019062300...
# 14          Beto O'Rourke  https://images.c-span.org/Files/bad/2019070219...
# 15               Tim Ryan  https://images.c-span.org/Files/9a4/2019062300...
# 16         Bernie Sanders  https://images.c-span.org/Files/6d9/2019062223...
# 17         Joe Sestak Jr.  https://images.c-span.org/Files/17e/2018102113...
# 18          Eric Swalwell  https://images.c-span.org/Files/d6f/2019062223...
# 19       Elizabeth Warren  https://images.c-span.org/Files/904/2019062921...
# 20    Marianne Williamson  https://images.c-span.org/Files/266/2019062222...
# 21            Andrew Yang  https://images.c-span.org/Files/876/2019062223...
# 22     Bill de Blasio Jr.  https://images.c-span.org/Files/506/2019062423...
#
#                                          Official Bio  \
# 0   <a href="http://bioguide.congress.gov/scripts/...
# 1   <a href="http://bioguide.congress.gov/scripts/...
# 2   <a href="http://bioguide.congress.gov/scripts/...
# 3                                                None
# 4                                                None
# 5                                                None
# 6   <a href="http://bioguide.congress.gov/scripts/...
# 7   <a href="http://bioguide.congress.gov/scripts/...
# 8   <a href="http://bioguide.congress.gov/scripts/...
# 9   <a href="http://bioguide.congress.gov/scripts/...
# 10                                               None
# 11  <a href="http://bioguide.congress.gov/scripts/...
# 12  <a href="http://bioguide.congress.gov/scripts/...
# 13  <a href="http://bioguide.congress.gov/scripts/...
# 14  <a href="http://bioguide.congress.gov/scripts/...
# 15  <a href="http://bioguide.congress.gov/scripts/...
# 16  <a href="http://bioguide.congress.gov/scripts/...
# 17  <a href="http://bioguide.congress.gov/scripts/...
# 18  <a href="http://bioguide.congress.gov/scripts/...
# 19  <a href="http://bioguide.congress.gov/scripts/...
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                           Description  \
# 0   [Michael Farrand Bennet is an American busines...
# 1   [Joseph Robinette Biden Jr. is an American pol...
# 2   [Cory Anthony Booker is an American politician...
# 3   [On the C-SPAN Networks:Steve Bullock is a Gov...
# 4   [On the C-SPAN Networks:Pete Buttigieg is a Ma...
# 5   [On the C-SPAN Networks:Julian Castro was a Se...
# 6   [John Kevin Delaney is an American politician ...
# 7   [Tulsi Gabbard is an American politician servi...
# 8   [Kirsten Elizabeth Gillibrand is an American a...
# 9   [Kamala Devi Harris is an American attorney an...
# 10  [On the C-SPAN Networks:John W. Hickenlooper w...
# 11  [Jay Robert Inslee is an American politician, ...
# 12  [Amy Jean Klobuchar is an American lawyer and ...
# 13  [Seth Wilbur Moulton is an American former Mar...
# 14  [Robert Francis "Beto" O'Rourke is an American...
# 15  [On the C-SPAN Networks:Tim Ryan has 436 video...
# 16  [Bernard Sanders is an American politician ser...
# 17  [Joseph Ambrose "Joe" Sestak, Jr. is an Americ...
# 18  [Eric Michael Swalwell Jr. is an American poli...
# 19  [Elizabeth Ann Warren is an American politicia...
# 20  [On the C-SPAN Networks:Marianne Williamson is...
# 21  [On the C-SPAN Networks:Andrew Yang is a Found...
# 22  [On the C-SPAN Networks:Bill de Blasio Jr. is ...
#
#                                                Titles
# 0                       [U.S. Senator, D-CO View Map]
# 1   [U.S. Vice President, United StatesD, U.S. Sen...
# 2   [U.S. Senator, D-NJ View Map, Mayor, Newark, N...
# 3   [Governor, MontanaD-Montana, Chair, Democratic...
# 4                            [Mayor, South Bend, IND]
# 5   [Secretary, Department of Housing and Urban De...
# 6   [U.S. Representative, D-MD 6th View Map, U.S. ...
# 7   [U.S. Representative, D-HI 2nd View Map, Veter...
# 8   [U.S. Senator, D-NY View Map, U.S. Representat...
# 9   [U.S. Senator, D-CA View Map, District Attorne...
# 10  [Chair, National Governors Association, Govern...
# 11  [Governor, Washington (State)D-Washington, U.S...
# 12  [U.S. Senator, D-MN View Map, County Attorney,...
# 13           [U.S. Representative, D-MA 6th View Map]
# 14  [U.S. Representative, D-TX 16th View Map, U.S....
# 15  [U.S. Representative, D-OH 13th View Map, U.S....
# 16  [U.S. Senator, I-VT View Map, U.S. Senator-Ele...
# 17  [Vice Admiral, U.S. Navy, U.S. Representative,...
# 18  [U.S. Representative, D-CA 15th View Map, U.S....
# 19  [U.S. Senator, D-MA View Map, Professor, Harva...
# 20                                           [Author]
# 21     [Founder and CEO, Venture for America, Author]
# 22  [Mayor, New York, NYD, Public Advocate, New Yo...
